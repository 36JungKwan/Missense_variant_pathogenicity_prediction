# %%
import pandas as pd
import numpy as np

# 1. ĐỌC DỮ LIỆU
# Thay bằng đường dẫn file Parquet đã có VEP của bạn
df = pd.read_parquet(r"D:\variant_data\clinvar_dbsnp_vep_merged_final.parquet")

df
# Out:
#              Variant_ID  #AlleleID                       Type  \
# 0         1_1014042_G_A   446939.0  single nucleotide variant
# 1         1_1014228_G_A   389314.0  single nucleotide variant
# 2         1_1014401_G_A        NaN                        NaN
# 3         1_1014471_G_C   446981.0  single nucleotide variant
# 4         1_1020183_G_C   364282.0  single nucleotide variant
# ...                 ...        ...                        ...
# 129945  X_155524537_G_A        NaN                        NaN
# 129946  X_155545128_G_T  2703929.0  single nucleotide variant
# 129947  X_155545219_C_T  3343405.0  single nucleotide variant
# 129948  X_156009834_G_A   706348.0  single nucleotide variant
# 129949   Y_13323634_C_T  2759141.0  single nucleotide variant
#
#                                                 Name    GeneID GeneSymbol  \
# 0            NM_005101.4(ISG15):c.62G>A (p.Ser21Asn)    9636.0      ISG15
# 1           NM_005101.4(ISG15):c.248G>A (p.Ser83Asn)    9636.0      ISG15
# 2                                                NaN       NaN        NaN
# 3          NM_005101.4(ISG15):c.491G>C (p.Arg164Pro)    9636.0      ISG15
# 4              NM_198576.4(AGRN):c.11G>C (p.Arg4Pro)  375790.0       AGRN
# ...                                              ...       ...        ...
# 129945                                           NaN       NaN        NaN
# 129946      NM_018196.4(TMLHE):c.149C>A (p.Thr50Asn)   55217.0      TMLHE
# 129947       NM_018196.4(TMLHE):c.58G>A (p.Gly20Arg)   55217.0      TMLHE
# 129948      NM_002186.3(IL9R):c.991G>A (p.Gly331Arg)    3581.0       IL9R
# 129949  NM_001258249.2(UTY):c.3197G>A (p.Arg1066His)    7404.0        UTY
#
#            HGNC_ID  ClinicalSignificance  ClinSigSimple  \
# 0        HGNC:4053  Benign/Likely benign            0.0
# 1        HGNC:4053                Benign            0.0
# 2              NaN                   NaN            NaN
# 3        HGNC:4053         Likely benign            0.0
# 4         HGNC:329                Benign            0.0
# ...            ...                   ...            ...
# 129945         NaN                   NaN            NaN
# 129946  HGNC:18308         Likely benign            0.0
# 129947  HGNC:18308         Likely benign            0.0
# 129948   HGNC:6030                Benign            0.0
# 129949  HGNC:12638         Likely benign            0.0
#
#                                              PhenotypeIDS  ...         gene  \
# 0       MONDO:MONDO:0014502,MedGen:C4015293,OMIM:61612...  ...          NaN
# 1       MedGen:CN169374|MONDO:MONDO:0014502,MedGen:C40...  ...          NaN
# 2                                                     NaN  ...   ISG15:9636
# 3       MONDO:MONDO:0014502,MedGen:C4015293,OMIM:61612...  ...          NaN
# 4       MONDO:MONDO:0014052,MedGen:C3808739,OMIM:61512...  ...          NaN
# ...                                                   ...  ...          ...
# 129945                                                NaN  ...  TMLHE:55217
# 129946                                    MedGen:CN169374  ...          NaN
# 129947                                    MedGen:CN169374  ...          NaN
# 129948                                    MedGen:C3661900  ...          NaN
# 129949                                    MedGen:CN169374  ...          NaN
#
#        clnsig                      clnhgvs  \
# 0         NaN                          NaN
# 1         NaN                          NaN
# 2         3|3    NC_000001.11:g.1014401G>A
# 3         NaN                          NaN
# 4         NaN                          NaN
# ...       ...                          ...
# 129945    4|4  NC_000023.11:g.155524537G>A
# 129946    NaN                          NaN
# 129947    NaN                          NaN
# 129948    NaN                          NaN
# 129949    NaN                          NaN
#
#                                                     clndn  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Mendelian_susceptibility_to_mycobacterial_dise...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 129945  Cerebellar_vermis_hypoplasia/Corpus_callosum\x...
# 129946                                                NaN
# 129947                                                NaN
# 129948                                                NaN
# 129949                                                NaN
#
#                      clnrevstat                         clnacc   Source  \
# 0                           NaN                            NaN  ClinVar
# 1                           NaN                            NaN  ClinVar
# 2                 single|single  RCV000652452.8|RCV003953195.1    dbSNP
# 3                           NaN                            NaN  ClinVar
# 4                           NaN                            NaN  ClinVar
# ...                         ...                            ...      ...
# 129945  no_criteria|no_criteria  RCV000779662.1|RCV001258013.1    dbSNP
# 129946                      NaN                            NaN  ClinVar
# 129947                      NaN                            NaN  ClinVar
# 129948                      NaN                            NaN  ClinVar
# 129949                      NaN                            NaN  ClinVar
#
#                    ENSP                        HGVSc  \
# 0       ENSP00000496832    ENST00000649529.1:c.62G>A
# 1       ENSP00000496832   ENST00000649529.1:c.248G>A
# 2       ENSP00000496832   ENST00000649529.1:c.421G>A
# 3       ENSP00000496832   ENST00000649529.1:c.491G>C
# 4       ENSP00000368678    ENST00000379370.7:c.11G>C
# ...                 ...                          ...
# 129945  ENSP00000335261   ENST00000334398.8:c.277C>T
# 129946  ENSP00000335261   ENST00000334398.8:c.149C>A
# 129947  ENSP00000335261    ENST00000334398.8:c.58G>A
# 129948  ENSP00000244174  ENST00000244174.11:c.991G>A
# 129949  ENSP00000442047  ENST00000545955.6:c.3197G>A
#
#                                  HGVSp
# 0         ENSP00000496832.1:p.Ser21Asn
# 1         ENSP00000496832.1:p.Ser83Asn
# 2        ENSP00000496832.1:p.Gly141Ser
# 3        ENSP00000496832.1:p.Arg164Pro
# 4          ENSP00000368678.2:p.Arg4Pro
# ...                                ...
# 129945    ENSP00000335261.3:p.Arg93Cys
# 129946    ENSP00000335261.3:p.Thr50Asn
# 129947    ENSP00000335261.3:p.Gly20Arg
# 129948   ENSP00000244174.5:p.Gly331Arg
# 129949  ENSP00000442047.2:p.Arg1066His
#
# [129950 rows x 66 columns]

# %%
# ==========================================
# 3. CHẠY EDA (EXPLORATORY DATA ANALYSIS)
# ==========================================

print("=== 1. TỔNG QUAN TOÀN BỘ DATASET ===")
total_variants = len(df)
patho_count = df['Label'].sum()
benign_count = total_variants - patho_count
print(f"Tổng số Variant: {total_variants:,}")
print(f"Pathogenic (1): {patho_count:,} ({patho_count/total_variants*100:.2f}%)")
print(f"Benign (0): {benign_count:,} ({benign_count/total_variants*100:.2f}%)")
print(f"Tổng số Gene (VEP SYMBOL) unique: {df['SYMBOL'].nunique():,}")
print("-" * 50)
# Out:
# === 1. TỔNG QUAN TOÀN BỘ DATASET ===
# Tổng số Variant: 129,950
# Pathogenic (1): 30,254.0 (23.28%)
# Benign (0): 99,696.0 (76.72%)
# Tổng số Gene (VEP SYMBOL) unique: 12,336
# --------------------------------------------------

# %%
print("\n=== 3. THỐNG KÊ THEO CHROMOSOME ===")
# Thống kê số lượng theo từng Chromosome
chr_stats = df.groupby('CHROM').agg(
    Total_Variants=('Variant_ID', 'count'),
    Pathogenic_1=('Label', 'sum')
).reset_index()

chr_stats['Benign_0'] = chr_stats['Total_Variants'] - chr_stats['Pathogenic_1']
chr_stats['Patho_Ratio (%)'] = (chr_stats['Pathogenic_1'] / chr_stats['Total_Variants'] * 100).round(2)
# Sắp xếp theo lượng variant giảm dần
chr_stats = chr_stats.sort_values('Total_Variants', ascending=False)
print(chr_stats.to_string(index=False))
print("-" * 50)
# Out:
# === 3. THỐNG KÊ THEO CHROMOSOME ===
# CHROM  Total_Variants  Pathogenic_1  Benign_0  Patho_Ratio (%)
#     1           12435        2933.0    9502.0            23.59
#     2           10418        2838.0    7580.0            27.24
#     X            8303        2915.0    5388.0            35.11
#    17            7683        2017.0    5666.0            26.25
#     7            7610        1605.0    6005.0            21.09
#     3            7472        1946.0    5526.0            26.04
#    12            6905        1833.0    5072.0            26.55
#     5            6427        1111.0    5316.0            17.29
#    11            6278        1683.0    4595.0            26.81
#     9            6263        1147.0    5116.0            18.31
#    16            5767        1123.0    4644.0            19.47
#     6            5704         985.0    4719.0            17.27
#    19            4538        1060.0    3478.0            23.36
#    15            4456        1348.0    3108.0            30.25
#    14            4383        1032.0    3351.0            23.55
#    10            4123         830.0    3293.0            20.13
#     4            4076         644.0    3432.0            15.80
#     8            3905         568.0    3337.0            14.55
#    20            3284         729.0    2555.0            22.20
#    13            3052         638.0    2414.0            20.90
#    22            2682         466.0    2216.0            17.38
#    18            2405         444.0    1961.0            18.46
#    21            1780         359.0    1421.0            20.17
#     Y               1           0.0       1.0             0.00
# --------------------------------------------------

# %%
print("\n=== 4. THỐNG KÊ THEO GENE ===")
gene_stats = df.groupby('SYMBOL').agg(
    Total_Variants=('Variant_ID', 'count'),
    Pathogenic_1=('Label', 'sum')
).reset_index()

gene_stats['Benign_0'] = gene_stats['Total_Variants'] - gene_stats['Pathogenic_1']
# Lọc ra các Gene có cả 2 nhãn (Phục vụ cho Bộ 2 & 3 sau này)
gene_stats['Has_Both_Labels'] = (gene_stats['Pathogenic_1'] > 0) & (gene_stats['Benign_0'] > 0)

gene_stats_sorted = gene_stats.sort_values('Total_Variants', ascending=False)
print(gene_stats_sorted.to_string(index=False))
# Out:
# === 4. THỐNG KÊ THEO GENE ===
#     SYMBOL  Total_Variants  Pathogenic_1  Benign_0  Has_Both_Labels
#     DNAH11            1072          14.0    1058.0             True
#      KMT2D            1014          40.0     974.0             True
#       FBN1             677         614.0      63.0             True
#      BRCA2             661          45.0     616.0             True
#     ADGRV1             612          12.0     600.0             True
#      SCN1A             500         451.0      49.0             True
#      OBSCN             473           1.0     472.0             True
#      BRCA1             463          53.0     410.0             True
#      DNAH5             432          25.0     407.0             True
#       SACS             425          27.0     398.0             True
#       APOB             390          10.0     380.0             True
#      KMT2C             382           8.0     374.0             True
#     COL4A5             370         267.0     103.0             True
#       NSD1             332          96.0     236.0             True
#       ATRX             330          29.0     301.0             True
#      USH2A             328         195.0     133.0             True
#       MSH2             327          79.0     248.0             True
#      KAT6A             324           5.0     319.0             True
#      MACF1             309           6.0     303.0             True
#       TP53             308         173.0     135.0             True
#     COL2A1             308         189.0     119.0             True
#       CHD7             306          31.0     275.0             True
#       RAI1             306           5.0     301.0             True
#      ABCA4             306         285.0      21.0             True
#      EHMT1             298          10.0     288.0             True
#     COL1A1             293         197.0      96.0             True
#     COL7A1             287          94.0     193.0             True
#     SETBP1             280          11.0     269.0             True
#        DMD             276           8.0     268.0             True
#    CACNA1E             273           8.0     265.0             True
#     NOTCH1             272          12.0     260.0             True
#     HIVEP2             267           3.0     264.0             True
#    DYNC1H1             254          78.0     176.0             True
#     COL3A1             251         235.0      16.0             True
#       MYH7             241         224.0      17.0             True
#       PKD1             241          63.0     178.0             True
#        GLA             239         231.0       8.0             True
#     COL1A2             238         230.0       8.0             True
#     ARID1B             236          11.0     225.0             True
#      EP300             235          18.0     217.0             True
#       FBN2             229          33.0     196.0             True
#     ZNF469             228           7.0     221.0             True
#       FLNA             226          19.0     207.0             True
#        PAH             226         225.0       1.0             True
#    CACNA1H             222           2.0     220.0             True
#    CACNA1A             220          98.0     122.0             True
#         F8             220         188.0      32.0             True
#        SON             219           2.0     217.0             True
#    ANKRD11             217          15.0     202.0             True
#        NF1             217         182.0      35.0             True
#      KCNQ2             215         205.0      10.0             True
#       SETX             208           9.0     199.0             True
#     COL5A1             204          19.0     185.0             True
#      ATP7A             204          14.0     190.0             True
#      KMT2B             202          16.0     186.0             True
#      SCN2A             200         174.0      26.0             True
#     AHNAK2             197           0.0     197.0            False
#     COL6A3             192          13.0     179.0             True
#     GRIN2A             187          49.0     138.0             True
#       MTOR             187          20.0     167.0             True
#      ASXL1             185           1.0     184.0             True
#      ALMS1             182           7.0     175.0             True
#       TSC2             178          38.0     140.0             True
#    COL11A1             175           6.0     169.0             True
#      RP1L1             174           2.0     172.0             True
#     GRIN2B             174          58.0     116.0             True
#       ALPL             174         168.0       6.0             True
#       ABL1             173          22.0     151.0             True
#       FLNB             172          20.0     152.0             True
#       NBAS             171           5.0     166.0             True
#        GCK             170         162.0       8.0             True
#       INF2             170          28.0     142.0             True
#        ATM             169          38.0     131.0             True
#      MECP2             166          38.0     128.0             True
#     MED13L             166          14.0     152.0             True
#        OTC             162         152.0      10.0             True
#      PKHD1             161          97.0      64.0             True
#     ARID1A             161          14.0     147.0             True
#      BEST1             158         155.0       3.0             True
#       RELN             157           8.0     149.0             True
#        ENG             156          46.0     110.0             True
#       RYR1             154         105.0      49.0             True
#      KIF1A             153          65.0      88.0             True
#     COL4A3             153          92.0      61.0             True
#      MUC5B             152           0.0     152.0            False
#     ACVRL1             152         138.0      14.0             True
#      AKAP9             151           2.0     149.0             True
#      KCNB1             149          40.0     109.0             True
#      LAMA5             149           4.0     145.0             True
#         F9             148         130.0      18.0             True
#       CRB1             148         132.0      16.0             True
#      SYNE2             147           0.0     147.0            False
#      PTCH1             146          21.0     125.0             True
#        VHL             143         120.0      23.0             True
#       ANK2             143           4.0     139.0             True
#     KANSL1             142           4.0     138.0             True
#       GLI3             142           5.0     137.0             True
#     ZNF292             142           2.0     140.0             True
#      AHDC1             141           2.0     139.0             True
#    SMARCA2             139          65.0      74.0             True
#        GAA             138         123.0      15.0             True
#      FSIP2             136           5.0     131.0             True
#       LMNA             136         134.0       2.0             True
#      ATP7B             136         112.0      24.0             True
#    COL11A2             136           9.0     127.0             True
#      ASXL3             134           1.0     133.0             True
#      KMT2A             133          24.0     109.0             True
#     RNF213             133           9.0     124.0             True
#    SLC26A4             132         114.0      18.0             True
#      CDKL5             131          67.0      64.0             True
#      SETD2             131           3.0     128.0             True
#     COL4A4             130          67.0      63.0             True
#      SCN8A             127         100.0      27.0             True
#      KCNQ1             126         116.0      10.0             True
#     COL4A1             125         100.0      25.0             True
#      FOXG1             125          59.0      66.0             True
#      TCF20             125           1.0     124.0             True
#        DSP             124          15.0     109.0             True
#     COL6A1             123          21.0     102.0             True
#    SYNGAP1             123          39.0      84.0             True
#      SRRM2             123           0.0     123.0            False
#      RBM20             121          11.0     110.0             True
#       CFTR             121         110.0      11.0             True
#     TUBA1A             121         120.0       1.0             True
#      KAT6B             121           1.0     120.0             True
#      FANCA             120          53.0      67.0             True
#       POLQ             120           0.0     120.0            False
#    COL12A1             118           2.0     116.0             True
#     MYO15A             118          44.0      74.0             True
#       MYH9             117          27.0      90.0             True
#     ABCA12             117          18.0      99.0             True
#       FAT1             113           5.0     108.0             True
#      KCNT1             113          33.0      80.0             True
#       NPC1             112          98.0      14.0             True
#    SLC12A3             111          98.0      13.0             True
#       SPEN             111           1.0     110.0             True
#       ARSA             111         103.0       8.0             True
#      ALPK2             110           0.0     110.0            False
#         AR             110          88.0      22.0             True
#      SPAST             109          91.0      18.0             True
#       MSH6             108          28.0      80.0             True
#      KCNH2             108          97.0      11.0             True
#      DNHD1             107           3.0     104.0             True
#     PIEZO1             107           4.0     103.0             True
#     SPTAN1             107          19.0      88.0             True
#     SPTBN5             107           0.0     107.0            False
#      PACS2             106           1.0     105.0             True
#      IFIH1             106          26.0      80.0             True
#    CACNA1G             105          11.0      94.0             True
#      ABCC6             103          71.0      32.0             True
#     CARD11             101           7.0      94.0             True
#       ZEB2             101          10.0      91.0             True
#       PHEX             101          79.0      22.0             True
#      CDK13             100          16.0      84.0             True
#       OTOF             100          16.0      84.0             True
#      HNF1A             100          75.0      25.0             True
#      MYO7A             100          69.0      31.0             True
#       FAT2              99           0.0      99.0            False
#     SPTBN2              98          13.0      85.0             True
#       LRP2              98           5.0      93.0             True
#       CHD2              97          45.0      52.0             True
#     STARD9              97           0.0      97.0            False
#      BICD2              97          21.0      76.0             True
#       COMP              97          88.0       9.0             True
#     NEXMIF              97           0.0      97.0            False
#      HUWE1              97          34.0      63.0             True
#       TRIO              96          22.0      74.0             True
#      XIRP2              96           0.0      96.0            False
#     STXBP1              96          62.0      34.0             True
#        VWF              96          70.0      26.0             True
#      ACTA1              96          96.0       0.0            False
#    CACNA1S              96          13.0      83.0             True
#     SLC6A1              95          50.0      45.0             True
#       G6PD              95          92.0       3.0             True
#        RHO              95          89.0       6.0             True
#      LAMA2              95          12.0      83.0             True
#     PTPN11              95          88.0       7.0             True
#       TSC1              95           3.0      92.0             True
#      AUTS2              95           6.0      89.0             True
#       GLB1              94          83.0      11.0             True
#      CNGA3              94          81.0      13.0             True
#       CDH1              92           7.0      85.0             True
#     PCDH19              92          73.0      19.0             True
#      NPHS1              91          49.0      42.0             True
#     PKD1L1              91           0.0      91.0            False
#       MBD5              91           1.0      90.0             True
#       GLDC              91          77.0      14.0             True
#     ABCA13              91           0.0      91.0            False
#      AMER1              91           0.0      91.0            False
#      EPHB4              91          14.0      77.0             True
#       ASPM              90           1.0      89.0             True
#       GJB1              90          87.0       3.0             True
#      MED12              90          24.0      66.0             True
#       MLH1              89          63.0      26.0             True
#    RHOBTB2              89           7.0      82.0             True
#     PDGFRB              89          14.0      75.0             True
#       FAT4              89           1.0      88.0             True
#      SMPD1              88          78.0      10.0             True
#      SETD5              88          10.0      78.0             True
#       PCNT              88           0.0      88.0            False
#      PRR12              87           1.0      86.0             True
#      HMCN1              87           0.0      87.0            False
#      SYNE1              87           2.0      85.0             True
#       CASR              87          77.0      10.0             True
#      NIPBL              86          37.0      49.0             True
#    CACNA1C              86          26.0      60.0             True
#      TRRAP              85          12.0      73.0             True
#      ALG13              85           8.0      77.0             True
#       RPGR              84          22.0      62.0             True
#   SERPING1              84          64.0      20.0             True
#        BTD              84          79.0       5.0             True
#       AGXT              84          77.0       7.0             True
#        TTR              84          81.0       3.0             True
#       GJB2              84          77.0       7.0             True
#        RET              84          45.0      39.0             True
#      NAGLU              83          71.0      12.0             True
#       SOS2              83           2.0      81.0             True
#       POLG              83          66.0      17.0             True
#        NHS              83           1.0      82.0             True
#      HECW2              83          22.0      61.0             True
#      SCN5A              83          57.0      26.0             True
#      SCN4A              83          67.0      16.0             True
#       BPTF              82           4.0      78.0             True
#       BRAF              81          70.0      11.0             True
#      ABCC8              81          70.0      11.0             True
#         FH              81          74.0       7.0             True
#       RERE              80           9.0      71.0             True
#       ADNP              80           2.0      78.0             True
#      ABCA1              80           9.0      71.0             True
#       BDP1              80           1.0      79.0             True
#      CLCN1              79          62.0      17.0             True
#      KIF5A              79          24.0      55.0             True
#       SOS1              79          31.0      48.0             True
#       VCAN              78           0.0      78.0            False
#     COL5A2              78           8.0      70.0             True
#       CUBN              77           3.0      74.0             True
#        FN1              77           9.0      68.0             True
#     IQSEC2              77          11.0      66.0             True
#     HNRNPU              77           4.0      73.0             True
#       TGM1              77          59.0      18.0             True
#      DNAH9              77           2.0      75.0             True
#     SCN10A              76           0.0      76.0            False
#     SETD1B              76          11.0      65.0             True
#     CHRNA4              76           2.0      74.0             True
#       WNK2              75           0.0      75.0            False
#      LRTM3              75           0.0      75.0            False
#      DDX3X              75          73.0       2.0             True
#        TYR              75          73.0       2.0             True
#      TCOF1              74           3.0      71.0             True
#       CHD8              74           9.0      65.0             True
#    SLC22A5              74          61.0      13.0             True
#     SETD1A              73           3.0      70.0             True
#       PTEN              73          69.0       4.0             True
#       OPA1              73          33.0      40.0             True
#       GBA1              73          71.0       2.0             True
#      ZDBF2              73           0.0      73.0            False
#        ALK              72           8.0      64.0             True
#     TGFBR2              72          64.0       8.0             True
#       JAG1              72          17.0      55.0             True
#       PCLO              72           0.0      72.0            False
#       ACTB              71          71.0       0.0            False
#     COL4A2              71          12.0      59.0             True
#        ASL              71          64.0       7.0             True
#      DNAH1              71           2.0      69.0             True
#     DICER1              71          18.0      53.0             True
#       MFN2              71          66.0       5.0             True
#      LRRK2              71           7.0      64.0             True
#     SLC2A1              70          62.0       8.0             True
#      STAT3              70          52.0      18.0             True
#      PRKDC              70           0.0      70.0            False
#      HSPG2              69           5.0      64.0             True
#      MED13              69           3.0      66.0             True
#     ATP1A3              69          59.0      10.0             True
#      PALB2              69           0.0      69.0            False
#     DNAH17              69           5.0      64.0             True
#        CBS              69          65.0       4.0             True
#       RAG1              69          48.0      21.0             True
#      ASH1L              68           4.0      64.0             True
#      MAP1B              68           1.0      67.0             True
#      ELANE              68          52.0      16.0             True
#      ACADM              68          66.0       2.0             True
#      PSEN1              68          63.0       5.0             True
#      PDHA1              68          61.0       7.0             True
#       PMM2              67          65.0       2.0             True
#      CAPN3              67          58.0       9.0             True
#      KCNH1              67          11.0      56.0             True
#      KDM6B              67           0.0      67.0            False
#      TEX15              67           1.0      66.0             True
#      GRIN1              67          48.0      19.0             True
#       ARSB              66          59.0       7.0             True
#      CMYA5              66           0.0      66.0            False
#    COL27A1              66           2.0      64.0             True
#     ABCB11              66          42.0      24.0             True
#     NEDD4L              66           3.0      63.0             True
#      CENPF              66           0.0      66.0            False
#       SOD1              66          66.0       0.0            False
#      KMT2E              65           3.0      62.0             True
#      TRPV4              65          44.0      21.0             True
#      FRAS1              65           4.0      61.0             True
#       UMOD              65          52.0      13.0             True
#       CPS1              65          23.0      42.0             True
#      LAMA1              64           1.0      63.0             True
#       MMUT              64          62.0       2.0             True
#       WFS1              64          36.0      28.0             True
#       ACAN              64           3.0      61.0             True
#      ZFHX3              63           2.0      61.0             True
#       PHIP              63           7.0      56.0             True
#      PRPH2              63          58.0       5.0             True
#        APC              63           4.0      59.0             True
#    CPLANE1              62          13.0      49.0             True
#      GALNS              62          53.0       9.0             True
#     GABBR2              62           4.0      58.0             True
#      CDH23              62          25.0      37.0             True
#     TRIOBP              62           1.0      61.0             True
#       HCN1              62          19.0      43.0             True
#        MET              62           7.0      55.0             True
#     MYO18B              62           0.0      62.0            False
#      FGFR3              62          40.0      22.0             True
#     ZSWIM6              62           1.0      61.0             True
#       MLH3              61           0.0      61.0            False
#     IGSF10              61           0.0      61.0            False
#     ZNF462              61           1.0      60.0             True
#        CIC              61           5.0      56.0             True
#      FGFR2              61          48.0      13.0             True
#       EGFR              61          25.0      36.0             True
#       OTOG              61           2.0      59.0             True
#      PACS1              61           2.0      59.0             True
#       MDN1              61           0.0      61.0            False
#       RYR3              60           0.0      60.0            False
#      ASXL2              60           1.0      59.0             True
#     CAMK2B              60           5.0      55.0             True
#       OCA2              60          41.0      19.0             True
#       GALT              60          59.0       1.0             True
#     CELSR1              60           0.0      60.0            False
#        RS1              60          51.0       9.0             True
#      LAMA3              60           1.0      59.0             True
#     DYRK1A              59          17.0      42.0             True
#       CUX2              59           1.0      58.0             True
#         TG              59           7.0      52.0             True
#       NBEA              59           1.0      58.0             True
#      SATB2              59          14.0      45.0             True
#       DNM1              59          32.0      27.0             True
#      SMC1A              59          41.0      18.0             True
#      SPTA1              59          12.0      47.0             True
#      DCHS2              59           0.0      59.0            False
#       SOX9              58          32.0      26.0             True
#       DSPP              58           2.0      56.0             True
#       TERT              58          22.0      36.0             True
#       GALC              58          51.0       7.0             True
#      C2CD3              58           1.0      57.0             True
#      ERCC6              58           6.0      52.0             True
#       CHD3              58          27.0      31.0             True
#     GUCY2D              58          41.0      17.0             True
#       TCF4              58          27.0      31.0             True
#     RANBP2              58           3.0      55.0             True
#      FGFR1              57          40.0      17.0             True
#      KDM5C              57          21.0      36.0             True
#     DNAH10              57           0.0      57.0            False
#   SERPINA1              57          19.0      38.0             True
#     GABRB2              57          23.0      34.0             True
#     MYBPC3              57          25.0      32.0             True
#       CYBB              56          34.0      22.0             True
#      ADCY5              56          18.0      38.0             True
#     IFT140              56          13.0      43.0             True
#        HGD              56          49.0       7.0             True
#      BRIP1              55           2.0      53.0             True
#    SMARCA4              55          40.0      15.0             True
#      ALPK1              55           2.0      53.0             True
#     COL6A2              55          25.0      30.0             True
#      KDM6A              55           8.0      47.0             True
#      DNAH2              55           2.0      53.0             True
#      DCHS1              55           2.0      53.0             True
#        DCX              55          53.0       2.0             True
#       NPAT              55           0.0      55.0            False
#      CSF1R              55           6.0      49.0             True
#      EXPH5              54           0.0      54.0            False
#      SCN3A              54           6.0      48.0             True
#      IGSF1              54           2.0      52.0             True
#      KIF11              54           2.0      52.0             True
#    CCDC88C              54           1.0      53.0             True
#   CDC42BPB              54           9.0      45.0             True
#      DNAH7              54           4.0      50.0             True
#       RFX7              53           1.0      52.0             True
#       NSD2              53           6.0      47.0             True
#    SHROOM2              53           1.0      52.0             True
#     CHRNA2              53           2.0      51.0             True
#      KANK1              53           0.0      53.0            False
#       LRP5              53          40.0      13.0             True
#     CHAMP1              53           0.0      53.0            False
#       NOD2              52          16.0      36.0             True
#    ANKRD26              52           0.0      52.0            False
#     TMEM67              52          45.0       7.0             True
#     SLC1A2              52           4.0      48.0             True
#      SOX11              52          31.0      21.0             True
#       TP63              52          44.0       8.0             True
#       FLT4              52          14.0      38.0             True
#      DNAH8              52           1.0      51.0             True
#       OCRL              52          18.0      34.0             True
#      ARID2              52           1.0      51.0             True
#      HDAC4              51           3.0      48.0             True
#      PHKA2              51          10.0      41.0             True
#      FREM2              51           3.0      48.0             True
#     DNAH14              51           0.0      51.0            False
#       COPA              50           4.0      46.0             True
#     CPAMD8              50           2.0      48.0             True
#      HYDIN              50           0.0      50.0            False
#        MPZ              50          49.0       1.0             True
#       ANK3              50           1.0      49.0             True
#         F5              50           8.0      42.0             True
#      SCN9A              50          16.0      34.0             True
#     SCN11A              50           5.0      45.0             True
#     ATP1A2              50          40.0      10.0             True
#      FANCM              50           0.0      50.0            False
#      FANCB              49           3.0      46.0             True
#        SKI              49          10.0      39.0             True
#       SIK1              49           2.0      47.0             True
#      TRPM1              49           8.0      41.0             True
#      NACC1              49           6.0      43.0             True
#     ITGA2B              49          41.0       8.0             True
#     CAMTA1              49           4.0      45.0             True
#     SAMD9L              49           9.0      40.0             True
#       SPI1              49           0.0      49.0            False
#     MAGEL2              49           2.0      47.0             True
#       RAG2              49          39.0      10.0             True
#      RREB1              48           0.0      48.0            False
#        RB1              48          14.0      34.0             True
#       MTM1              48          28.0      20.0             True
#     HIVEP1              48           0.0      48.0            False
#      BAZ2B              48           1.0      47.0             True
#     PIK3CA              48          44.0       4.0             True
#   SNRNP200              47           9.0      38.0             True
#      GATA2              47          32.0      15.0             True
#    SHROOM3              47           0.0      47.0            False
#      FOXP1              47           4.0      43.0             True
#      ACTG1              47          45.0       2.0             True
#      TRPS1              47           4.0      43.0             True
#     ZBTB20              47          17.0      30.0             True
#      ITPR1              47          31.0      16.0             True
#        WAS              47          24.0      23.0             True
#      GNAO1              47          33.0      14.0             True
#       PCCB              47          42.0       5.0             True
#      IL2RG              47          24.0      23.0             True
#       FASN              47           0.0      47.0            False
#    KBTBD13              46           2.0      44.0             True
#     VPS13C              46           0.0      46.0            False
#     NFE2L2              46           9.0      37.0             True
#     KATNIP              46           0.0      46.0            False
#       H1-4              46           1.0      45.0             True
#     GABRB3              46          28.0      18.0             True
#       GFAP              46          33.0      13.0             True
#       GNAS              46          46.0       0.0            False
#      KIF22              46           7.0      39.0             True
#      PDZD2              46           0.0      46.0            False
#      XIRP1              46           0.0      46.0            False
#      EPAS1              46           1.0      45.0             True
#     CELSR2              46           2.0      44.0             True
#        BTK              46          35.0      11.0             True
#        KIT              46          25.0      21.0             True
#       TGM6              46           2.0      44.0             True
#      SRCAP              46           0.0      46.0            False
#      ZFHX4              46           0.0      46.0            False
#    ALDH7A1              46          43.0       3.0             True
#        TNC              45           3.0      42.0             True
#     PLA2G6              45          40.0       5.0             True
#       CRB2              45           8.0      37.0             True
#        BLM              45           5.0      40.0             True
#      STAT1              45          44.0       1.0             True
#      ZMIZ1              45           5.0      40.0             True
#       IRF6              45          36.0       9.0             True
#        DST              45           0.0      45.0            False
#      MYH14              45           5.0      40.0             True
#      ACTN2              45           5.0      40.0             True
#     TNRC6B              45           0.0      45.0            False
#       GPC3              45           3.0      42.0             True
#      DNMT1              45           5.0      40.0             True
#      RPE65              45          39.0       6.0             True
#      A2ML1              45           0.0      45.0            False
#      FREM1              45           2.0      43.0             True
#        LPL              45          38.0       7.0             True
#     RAD54L              44           5.0      39.0             True
#       MAPT              44          13.0      31.0             True
#      USP9X              44          14.0      30.0             True
#     FRMPD4              44           0.0      44.0            False
#      NR2F1              44          34.0      10.0             True
#    SPECC1L              44           7.0      37.0             True
#        ARX              44          17.0      27.0             True
#      FYCO1              44           0.0      44.0            False
#     CYFIP2              44          10.0      34.0             True
#        WT1              44          28.0      16.0             True
#     KIF26B              44           0.0      44.0            False
#       CHD4              44          22.0      22.0             True
#     MAP2K1              43          39.0       4.0             True
#      REV3L              43           1.0      42.0             True
#      ZFHX2              43           1.0      42.0             True
#      ITGB3              43          35.0       8.0             True
#      TECTA              43          16.0      27.0             True
#        F11              43          35.0       8.0             True
#       FMN1              43           0.0      43.0            False
#     PLXNA3              43           0.0      43.0            False
#      POLA1              43           4.0      39.0             True
#        EYS              42          13.0      29.0             True
#      BARD1              42           0.0      42.0            False
#     CELSR3              42          10.0      32.0             True
#       LDB3              42           2.0      40.0             True
#      LAMA4              42           0.0      42.0            False
#     ZNF407              42           1.0      41.0             True
#     TGFBR1              42          33.0       9.0             True
#      BICRA              42           1.0      41.0             True
#      NR5A1              42          36.0       6.0             True
#       ATL1              42          40.0       2.0             True
#    CYP11B1              42          36.0       6.0             True
#   ARHGEF28              42           0.0      42.0            False
#       TAF1              42          14.0      28.0             True
#     VPS13D              42           7.0      35.0             True
#       BCOR              41           0.0      41.0            False
#     CC2D2A              41          19.0      22.0             True
#     GABRA1              41          31.0      10.0             True
#       OFD1              41           4.0      37.0             True
#      KCNH5              41           4.0      37.0             True
#       TBX5              41          20.0      21.0             True
#      NTRK1              41          24.0      17.0             True
#     SRD5A2              41          33.0       8.0             True
#    ALDH5A1              41          32.0       9.0             True
#      FOXP3              41          17.0      24.0             True
#     PRUNE2              41           0.0      41.0            False
#       FLT3              41          25.0      16.0             True
#       MPDZ              40           0.0      40.0            False
#      TNNT2              40          37.0       3.0             True
#       RAF1              40          21.0      19.0             True
#      ALPK3              40           0.0      40.0            False
#    PKHD1L1              40           3.0      37.0             True
#      PTPRQ              40           1.0      39.0             True
#     FBXO11              40          21.0      19.0             True
#       PRF1              40          37.0       3.0             True
#      ETFDH              40          34.0       6.0             True
#       FAT3              40           0.0      40.0            False
#       EZH2              40          20.0      20.0             True
#      ABCA3              40          20.0      20.0             True
#       AGRN              40           3.0      37.0             True
#       OAS1              40           1.0      39.0             True
#       GNB1              40          25.0      15.0             True
#      WDFY3              40           4.0      36.0             True
#      DDX41              40           2.0      38.0             True
#      TANC2              40           0.0      40.0            False
#     PNPLA1              39          20.0      19.0             True
#     SPTBN1              39          10.0      29.0             True
#     VPS13B              39           5.0      34.0             True
#     ADGRG4              39           0.0      39.0            False
#     CYP1B1              39          29.0      10.0             True
#        CEL              39           0.0      39.0            False
#       MYLK              39           2.0      37.0             True
#      KDM3B              39           5.0      34.0             True
#      G6PC1              39          36.0       3.0             True
#       SPEG              39           0.0      39.0            False
#        ZAN              38           0.0      38.0            False
#    SHROOM4              38           0.0      38.0            False
#      SOX10              38          23.0      15.0             True
#     VPS13A              38           2.0      36.0             True
#       CDON              38           3.0      35.0             True
#      SORL1              38           0.0      38.0            False
#      MYOM2              38           0.0      38.0            False
#       SYNM              38           0.0      38.0            False
#      CLCN7              38          21.0      17.0             True
#       INSR              38          23.0      15.0             True
#     GABRG2              38          29.0       9.0             True
#       LYST              38           6.0      32.0             True
#     JMJD1C              38           1.0      37.0             True
#      MKI67              38           0.0      38.0            False
#      CHIT1              38           0.0      38.0            False
#     PIK3R2              38           3.0      35.0             True
#      DEAF1              38          29.0       9.0             True
#     SHANK1              38           1.0      37.0             True
#      EP400              37           0.0      37.0            False
#    TMPRSS3              37          27.0      10.0             True
#      MYO7B              37           0.0      37.0            False
#       EPG5              37           2.0      35.0             True
#        ATR              37           2.0      35.0             True
#       PLP1              37          34.0       3.0             True
#    SIPA1L3              37           0.0      37.0            False
#        NIN              37           0.0      37.0            False
#     SEC16A              37           0.0      37.0            False
#   KIAA1549              37           1.0      36.0             True
#     CD40LG              37          21.0      16.0             True
#       AFF2              37           2.0      35.0             True
#      MYO5B              37           9.0      28.0             True
#       PAX3              37          29.0       8.0             True
#        TEK              37           9.0      28.0             True
#       PEX1              37          12.0      25.0             True
#       WNK1              37           1.0      36.0             True
#   KIAA0586              37           2.0      35.0             True
#      IGFN1              37           0.0      37.0            False
#       AIRE              37          21.0      16.0             True
#      DMXL1              37           0.0      37.0            False
#      DHX30              36           9.0      27.0             True
#       DLC1              36           0.0      36.0            False
#        BSN              36           0.0      36.0            False
#      NLRP1              36           5.0      31.0             True
#     SHANK2              36           2.0      34.0             True
#      PRRT2              36           8.0      28.0             True
#      PLCG2              36           6.0      30.0             True
#    IGHMBP2              36          20.0      16.0             True
#      RUNX1              36          11.0      25.0             True
#     BCL11B              36           3.0      33.0             True
#     BCKDHB              36          32.0       4.0             True
#      SAMD9              36           5.0      31.0             True
#       NEFH              36           0.0      36.0            False
#     TNRC18              36           0.0      36.0            False
#      KCNQ5              36           5.0      31.0             True
#      FOCAD              36           1.0      35.0             True
#     ZBTB18              36          19.0      17.0             True
#      PPM1D              36           1.0      35.0             True
#      HNF4A              35          30.0       5.0             True
#     COL6A5              35           0.0      35.0            False
#        EVC              35           2.0      33.0             True
#    FAM111A              35           5.0      30.0             True
#     GREB1L              35          12.0      23.0             True
#     CARD14              35           6.0      29.0             True
#        APP              35          15.0      20.0             True
#       JAK3              35          17.0      18.0             True
#      PLCE1              35           3.0      32.0             True
#      SCN7A              35           0.0      35.0            False
#     EEF1A2              35          29.0       6.0             True
#      MYOM1              35           0.0      35.0            False
#        ADA              35          27.0       8.0             True
#      RDH12              35          33.0       2.0             True
#     TUBB2A              35          26.0       9.0             True
#      CLCN4              35          15.0      20.0             True
#      HOGA1              35          30.0       5.0             True
#      KCNJ2              35          31.0       4.0             True
#       MYH3              35          15.0      20.0             True
#      NALCN              35          28.0       7.0             True
#      CNGB1              35           3.0      32.0             True
#      MYO16              34           0.0      34.0            False
#       HEXA              34          30.0       4.0             True
#    CYP17A1              34          29.0       5.0             True
#     CEP295              34           1.0      33.0             True
#   CDK5RAP2              34           2.0      32.0             True
#    SLC40A1              34          22.0      12.0             True
#      NLRP5              34           3.0      31.0             True
#      HELZ2              34           0.0      34.0            False
#       HCN4              34          10.0      24.0             True
#      LMX1B              34          28.0       6.0             True
#       TNS1              34           0.0      34.0            False
#      CASZ1              34           1.0      33.0             True
#      TRIM8              34           0.0      34.0            False
#      NR0B1              34          13.0      21.0             True
#       TBCD              34          11.0      23.0             True
#       SDHB              34          30.0       4.0             True
#      LONP1              34           1.0      33.0             True
#      MCCC2              34          32.0       2.0             True
#      SALL1              34           1.0      33.0             True
#      DNAH3              34           3.0      31.0             True
#     GEMIN4              34           1.0      33.0             True
#   ARHGAP31              34           0.0      34.0            False
#      MTCL1              33           0.0      33.0            False
#        RP2              33           7.0      26.0             True
#      KCNA2              33          23.0      10.0             True
#       ROR2              33          10.0      23.0             True
#        TPO              33          17.0      16.0             True
#       FGD1              33           6.0      27.0             True
#      CENPE              33           1.0      32.0             True
#      CSMD1              33           0.0      33.0            False
#       PAX6              33          31.0       2.0             True
#      PANK2              33          27.0       6.0             True
#       ASPA              33          29.0       4.0             True
#      KCNQ3              33          17.0      16.0             True
#     TRIP11              33           1.0      32.0             True
#       NRAP              33           0.0      33.0            False
#       UTRN              33           0.0      33.0            False
#     AKAP13              33           0.0      33.0            False
#      POLD1              33           3.0      30.0             True
#       IQCN              33           0.0      33.0            False
#       SMC3              33          27.0       6.0             True
#   ADAMTS18              33           1.0      32.0             True
#       GJA1              33          32.0       1.0             True
#       GJA8              33          18.0      15.0             True
#      BUB1B              33           0.0      33.0            False
#      MYO9A              33           0.0      33.0            False
#     EIF2B5              33          28.0       5.0             True
#       SFI1              33           0.0      33.0            False
#     COL6A6              33           0.0      33.0            False
#       SGCA              33          31.0       2.0             True
#      CFHR4              32           0.0      32.0            False
#    CACNA1F              32           7.0      25.0             True
#     SPAG17              32           1.0      31.0             True
#     CEP250              32           0.0      32.0            False
#     ADCY10              32           0.0      32.0            False
#     MCM3AP              32           4.0      28.0             True
#      MYT1L              32          12.0      20.0             True
#       FKRP              32          30.0       2.0             True
#      ACAT1              32          29.0       3.0             True
#    SLC26A3              32          11.0      21.0             True
#      STK11              32          21.0      11.0             True
#      DHX37              32           5.0      27.0             True
#       UBR1              32           2.0      30.0             True
#      GLRA1              32          23.0       9.0             True
#       THRB              32          27.0       5.0             True
#     SLC4A1              32          24.0       8.0             True
#      CHRNE              32          24.0       8.0             True
#       TSHR              32          25.0       7.0             True
#      WDFY4              32           0.0      32.0            False
#       TET2              32           1.0      31.0             True
#     PITRM1              32           1.0      31.0             True
#       CHAT              32          13.0      19.0             True
# ...
#     ADHFE1               1           0.0       1.0            False
#       ADH5               1           1.0       0.0            False
#      ADH1A               1           0.0       1.0            False
#      ZFPL1               1           0.0       1.0            False
#      ADRM1               1           0.0       1.0            False
#     NMNAT2               1           1.0       0.0            False
#       NME6               1           0.0       1.0            False
#       NME5               1           0.0       1.0            False
#       NME4               1           0.0       1.0            False
#       NME1               1           0.0       1.0            False
#        NMB               1           0.0       1.0            False
#     NKX3-1               1           0.0       1.0            False
#     NKX2-4               1           0.0       1.0            False
#     NKX2-3               1           0.0       1.0            False
#     NKX1-2               1           0.0       1.0            False
#     NKX1-1               1           0.0       1.0            False
#      GSTM5               1           0.0       1.0            False
#      GSTA5               1           0.0       1.0            False
#      GSTA4               1           0.0       1.0            False
#      GSTA3               1           0.0       1.0            False
#      GSPT2               1           0.0       1.0            False
#       GSG1               1           0.0       1.0            False
#    ADCYAP1               1           0.0       1.0            False
#       ZHX1               1           0.0       1.0            False
#    ZFYVE21               1           0.0       1.0            False
#     ZFYVE1               1           0.0       1.0            False
#     ADGRL3               1           0.0       1.0            False
#     NHLRC3               1           0.0       1.0            False
#      NKAPL               1           0.0       1.0            False
#       NIT2               1           0.0       1.0            False
#       NIT1               1           0.0       1.0            False
#  NIPSNAP3B               1           0.0       1.0            False
#   NIPSNAP2               1           0.0       1.0            False
#     NIPAL2               1           0.0       1.0            False
#     NIPAL1               1           0.0       1.0            False
#       NIP7               1           0.0       1.0            False
#      MYEF2               1           0.0       1.0            False
#      ZMYM4               1           0.0       1.0            False
#      ADCY4               1           0.0       1.0            False
#      ADCY2               1           0.0       1.0            False
#      ADAP1               1           0.0       1.0            False
#    ZKSCAN1               1           0.0       1.0            False
#        GRP               1           0.0       1.0            False
#       NGFR               1           0.0       1.0            False
#     NFKBID               1           0.0       1.0            False
#     GUCA1C               1           0.0       1.0            False
#      GTSF1               1           1.0       0.0            False
#   KRTAP4-7               1           0.0       1.0            False
#   KRTAP4-6               1           0.0       1.0            False
#   KRTAP4-3               1           0.0       1.0            False
#   KRTAP4-2               1           0.0       1.0            False
#     ZNF135               1           0.0       1.0            False
#      ZNF10               1           0.0       1.0            False
#    ZMYND15               1           0.0       1.0            False
#       HPF1               1           0.0       1.0            False
#      HOXD4               1           0.0       1.0            False
#     HS3ST6               1           1.0       0.0            False
#     HS3ST1               1           0.0       1.0            False
#      NHSL3               1           0.0       1.0            False
#       GZMM               1           0.0       1.0            False
#       GZMH               1           0.0       1.0            False
#       GYPE               1           0.0       1.0            False
#      GULP1               1           0.0       1.0            False
#      ACYP1               1           0.0       1.0            False
#      ZNF22               1           0.0       1.0            False
#     ZNF219               1           0.0       1.0            False
#     ZNF182               1           0.0       1.0            False
#     ZNF165               1           0.0       1.0            False
#       KSR1               1           0.0       1.0            False
#   KRTAP6-2               1           0.0       1.0            False
#     GTF2F1               1           0.0       1.0            False
#     GTF2E1               1           0.0       1.0            False
#    GTF2A1L               1           0.0       1.0            False
#      GSTZ1               1           0.0       1.0            False
#      GSTP1               1           0.0       1.0            False
#     ACTRT2               1           0.0       1.0            False
#      LCA5L               1           0.0       1.0            False
#       LBX2               1           0.0       1.0            False
#       LBX1               1           0.0       1.0            False
#      LASP1               1           0.0       1.0            False
#       LAP3               1           0.0       1.0            False
#     LANCL1               1           0.0       1.0            False
#     ACTBL2               1           0.0       1.0            False
#     ZNF282               1           0.0       1.0            False
#     ZNF276               1           0.0       1.0            False
#      ZNF26               1           0.0       1.0            False
#     ZNF232               1           0.0       1.0            False
#     GTPBP1               1           0.0       1.0            False
#     GTF3C6               1           0.0       1.0            False
#     NFE2L1               1           0.0       1.0            False
#       NFE2               1           0.0       1.0            False
#      H3C11               1           1.0       0.0            False
#       H3-4               1           0.0       1.0            False
#     H2BC17               1           0.0       1.0            False
#      H2BC1               1           0.0       1.0            False
#     H2AC17               1           1.0       0.0            False
#     H2AC16               1           1.0       0.0            False
#       H1-7               1           0.0       1.0            False
#      NETO2               1           0.0       1.0            False
#       HAMP               1           1.0       0.0            False
#       HAGH               1           0.0       1.0            False
#      HACE1               1           0.0       1.0            False
#     ZNF326               1           0.0       1.0            False
#     ZNF319               1           0.0       1.0            False
#     ZNF311               1           0.0       1.0            False
#      ZNF30               1           0.0       1.0            False
#       ZNF3               1           0.0       1.0            False
#     HOXC11               1           0.0       1.0            False
#      HOXA7               1           0.0       1.0            False
#      HAUS2               1           0.0       1.0            False
#       HAS3               1           0.0       1.0            False
#     HAPLN2               1           0.0       1.0            False
#     ZNF397               1           0.0       1.0            False
#    ZNF385B               1           0.0       1.0            False
#    ZNF385A               1           0.0       1.0            False
#     ZNF37A               1           0.0       1.0            False
#     ZNF365               1           0.0       1.0            False
#    ZNF354C               1           0.0       1.0            False
#      HACD2               1           0.0       1.0            False
#       H4C9               1           1.0       0.0            False
#       NEK8               1           0.0       1.0            False
#      HOXD1               1           0.0       1.0            False
#      HOXC5               1           0.0       1.0            False
#      NDST3               1           0.0       1.0            False
#      NDRG1               1           0.0       1.0            False
#      NDOR1               1           0.0       1.0            False
#      ZNF48               1           0.0       1.0            False
#     ZNF454               1           0.0       1.0            False
#     ZNF446               1           0.0       1.0            False
#     ZNF436               1           0.0       1.0            False
#     ZNF408               1           0.0       1.0            False
#      ACSL3               1           0.0       1.0            False
#     NECAP1               1           0.0       1.0            False
#     NECAB2               1           0.0       1.0            False
#     NDUFS4               1           0.0       1.0            False
#     NDUFC1               1           0.0       1.0            False
#     NDUFB9               1           0.0       1.0            False
#     NDUFB5               1           0.0       1.0            False
#     HOXC12               1           0.0       1.0            False
#      HDHD3               1           0.0       1.0            False
#      HDHD2               1           0.0       1.0            False
#     HDGFL1               1           0.0       1.0            False
#      HDAC1               1           1.0       0.0            False
#      HMHB1               1           0.0       1.0            False
#     HMGXB4               1           0.0       1.0            False
#     ACOT11               1           0.0       1.0            False
#      ACMSD               1           0.0       1.0            False
#       ACLY               1           0.0       1.0            False
#       ACE2               1           0.0       1.0            False
#     ZNF497               1           0.0       1.0            False
#      HCAR1               1           0.0       1.0            False
#    NDUFAF2               1           0.0       1.0            False
#     NDUFA6               1           0.0       1.0            False
#     NDUFA5               1           0.0       1.0            False
#    NDUFA11               1           1.0       0.0            False
#     NCKAP1               1           0.0       1.0            False
#       NCK1               1           0.0       1.0            False
#      NCEH1               1           0.0       1.0            False
#      NBPF6               1           0.0       1.0            False
#      NBPF3               1           0.0       1.0            False
#      ACBD7               1           0.0       1.0            False
#      ACBD3               1           0.0       1.0            False
#      ACAP1               1           0.0       1.0            False
#     ZNF521               1           0.0       1.0            False
#     HOXA10               1           0.0       1.0            False
#      HOXA1               1           0.0       1.0            False
#       HOPX               1           0.0       1.0            False
#      HOOK3               1           1.0       0.0            False
#     HEATR6               1           0.0       1.0            False
#       NDE1               1           0.0       1.0            False
#      NDC80               1           0.0       1.0            False
#     NAP1L5               1           0.0       1.0            False
#      HERC3               1           0.0       1.0            False
#      HEMGN               1           0.0       1.0            False
#      HHATL               1           0.0       1.0            False
#        HFE               1           1.0       0.0            False
#       HEY2               1           0.0       1.0            False
#     ZNF691               1           0.0       1.0            False
#     ZNF689               1           0.0       1.0            False
#     ZNF684               1           0.0       1.0            False
#     ZNF654               1           0.0       1.0            False
#     ZNF652               1           0.0       1.0            False
#     ZNF628               1           0.0       1.0            False
#     ZNF620               1           0.0       1.0            False
#     ZNF605               1           0.0       1.0            False
#      NCOA5               1           0.0       1.0            False
#     NCKAP5               1           0.0       1.0            False
#       NADK               1           0.0       1.0            False
#      NABP1               1           0.0       1.0            False
#       NAB2               1           0.0       1.0            False
#      HINT1               1           1.0       0.0            False
#      ABTB3               1           0.0       1.0            False
#       ABRA               1           0.0       1.0            False
#     ZNF740               1           0.0       1.0            False
#    ZNF705D               1           0.0       1.0            False
#     ZNF697               1           0.0       1.0            False
#     HEXIM1               1           0.0       1.0            False
#     HIGD1C               1           0.0       1.0            False
#     HIGD1A               1           0.0       1.0            False
#     HIF1AN               1           0.0       1.0            False
#       HHEX               1           0.0       1.0            False
#    NAPEPLD               1           0.0       1.0            False
#       NAPB               1           0.0       1.0            False
#     A4GALT               1           0.0       1.0            False
#      ABHD6               1           0.0       1.0            False
#    ABHD17A               1           0.0       1.0            False
#      ABCG2               1           0.0       1.0            False
#     ZSWIM8               1           0.0       1.0            False
#     ZSWIM4               1           0.0       1.0            False
#      AAMDC               1           0.0       1.0            False
#    AADACL3               1           0.0       1.0            False
#     ZRANB1               1           0.0       1.0            False
#    L3MBTL2               1           0.0       1.0            False
#    L3HYPDH               1           0.0       1.0            False
#      HNF4G               1           0.0       1.0            False
#       HMX2               1           0.0       1.0            False
#    ZSCAN31               1           0.0       1.0            False
#    ZSCAN22               1           0.0       1.0            False
#    ZSCAN16               1           0.0       1.0            False
#    ABHD14A               1           0.0       1.0            False
#     ZNF865               1           0.0       1.0            False
#     ZNF800               1           0.0       1.0            False
#       ZNF8               1           0.0       1.0            False
#      ZNF79               1           0.0       1.0            False
#     LACTB2               1           0.0       1.0            False
#       ABI3               1           0.0       1.0            False
#      AADAC               1           0.0       1.0            False
#      ABCD2               1           0.0       1.0            False
#      ZNRF1               1           0.0       1.0            False
#     ZNHIT2               1           0.0       1.0            False
#      ZNF92               1           0.0       1.0            False
#     ZNF883               1           0.0       1.0            False
#     ABLIM1               1           0.0       1.0            False
#       ABL2               1           0.0       1.0            False
#      ABCG1               1           0.0       1.0            False

# %%
# 2. MÃ HÓA ĐỘ TIN CẬY REVIEW STATUS (DÙNG CHO BỘ 3)
print("[2/5] Đang đánh giá Rank cho ReviewStatus...")
review_priority = {
    'practice guideline': 5,
    'reviewed by expert panel': 4,
    'criteria provided, multiple submitters, no conflicts': 3,
    'criteria provided, single submitter': 2,
    'criteria provided, conflicting classifications': 1
}
# Các loại 'no classification', 'no assertion' sẽ mặc định nhận rank 0
df['Review_Rank'] = df['ReviewStatus'].map(review_priority).fillna(0)

# =========================================================
# THUẬT TOÁN GREEDY CHIA CHROMOSOME (ĐẢM BẢO KHÔNG TRÙNG LẶP)
# =========================================================
print("[3/5] Đang chạy thuật toán phân bổ Chromosome (80-10-10)...")
chr_stats = df['CHROM'].value_counts().reset_index()
chr_stats.columns = ['CHROM', 'Count']

total_variants = chr_stats['Count'].sum()
target_train = total_variants * 0.80
target_val = total_variants * 0.10
target_test = total_variants * 0.10

splits = {'Train': [], 'Val': [], 'Test': []}
current_counts = {'Train': 0, 'Val': 0, 'Test': 0}
targets = {'Train': target_train, 'Val': target_val, 'Test': target_test}

# Lặp qua các Chromosome từ lớn nhất đến nhỏ nhất
for _, row in chr_stats.iterrows():
    chrom = row['CHROM']
    count = row['Count']
    
    # Tìm rương đang thiếu hụt nhiều nhất so với target
    deficits = {k: targets[k] - current_counts[k] for k in targets}
    best_split = max(deficits, key=deficits.get)
    
    # Gán Chromosome vào rương đó
    splits[best_split].append(chrom)
    current_counts[best_split] += count

print("\n--- KẾT QUẢ CHIA CHROMOSOME ---")
for k in splits:
    pct = current_counts[k] / total_variants * 100
    print(f"{k} ({pct:.2f}%): {splits[k]}")
print("--------------------------------\n")

# Gán cột Split vào DataFrame tổng
def get_split(chrom):
    if chrom in splits['Train']: return 'Train'
    elif chrom in splits['Val']: return 'Val'
    else: return 'Test'

df['Split'] = df['CHROM'].apply(get_split)

# =========================================================
# TẠO BỘ 1: CHỈ CHIA TRAIN/VAL/TEST THEO CHROMOSOME
# =========================================================
print("[4/5] Đang xuất Bộ 1...")
df_bo1 = df.copy()

# =========================================================
# TẠO BỘ 2: BỘ 1 + LỌC BỎ GENE CHỈ CÓ 1 NHÃN
# =========================================================
print("Đang xuất Bộ 2...")
# Đếm số lượng nhãn độc nhất của mỗi Gene
gene_label_counts = df_bo1.groupby('SYMBOL')['Label'].nunique()
# Giữ lại các Gene có đúng 2 nhãn (cả 0 và 1)
valid_genes = gene_label_counts[gene_label_counts == 2].index
df_bo2 = df_bo1[df_bo1['SYMBOL'].isin(valid_genes)].copy()

# =========================================================
# TẠO BỘ 3: BỘ 2 + DOWNSAMPLING 50:50 DỰA THEO REVIEW RANK
# =========================================================
print("Đang xuất Bộ 3 (Downsampling 50:50 thông minh)...")

# Bước A: Sắp xếp ưu tiên: Gene -> Label -> Rank ReviewStatus (Giảm dần)
df_bo3_temp = df_bo2.sort_values(by=['SYMBOL', 'Label', 'Review_Rank'], ascending=[True, True, False])

# Bước B: Đánh số thứ tự từng Variant trong cùng một nhóm (Gene + Label)
df_bo3_temp['Row_Num'] = df_bo3_temp.groupby(['SYMBOL', 'Label']).cumcount()

# Bước C: Đếm số lượng Patho và Benign của từng Gene
class_counts = df_bo3_temp.groupby(['SYMBOL', 'Label']).size().unstack(fill_value=0)
# Số lượng giới hạn = min(số lượng Patho, số lượng Benign)
class_counts['Min_Count'] = class_counts.min(axis=1)

# Bước D: Lọc bằng cách ghép (Merge) Min_Count vào data và cắt bỏ biến thể dư thừa
df_bo3 = df_bo3_temp.merge(class_counts[['Min_Count']], on='SYMBOL', how='left')
# Chỉ giữ lại các Variant có số thứ tự < Min_Count
df_bo3 = df_bo3[df_bo3['Row_Num'] < df_bo3['Min_Count']].copy()

# Dọn dẹp cột phụ
df_bo3 = df_bo3.drop(columns=['Row_Num', 'Min_Count'])
# Out:
# [2/5] Đang đánh giá Rank cho ReviewStatus...
# [3/5] Đang chạy thuật toán phân bổ Chromosome (80-10-10)...
#
# --- KẾT QUẢ CHIA CHROMOSOME ---
# Train (80.33%): ['1', '2', 'X', '17', '7', '3', '12', '5', '11', '9', '16', '6', '14', '8', '13', '21']
# Val (10.54%): ['19', '4', '22', '18']
# Test (9.13%): ['15', '10', '20', 'Y']
# --------------------------------
#
# [4/5] Đang xuất Bộ 1...
# Đang xuất Bộ 2...
# Đang xuất Bộ 3 (Downsampling 50:50 thông minh)...

# %%
def eda_dataset(df, name):
    print(f"============================================================")
    print(f"🌟 BÁO CÁO EDA CHI TIẾT: {name}")
    print(f"============================================================")
    
    # 1. TỔNG QUAN
    total_variants = len(df)
    total_genes = df['SYMBOL'].nunique()
    total_chroms = df['CHROM'].nunique()
    patho_count = df['Label'].sum()
    benign_count = total_variants - patho_count
    
    print("1. TỔNG QUAN KÍCH THƯỚC:")
    print(f"   - Tổng số biến thể: {total_variants:,}")
    print(f"   - Tổng số Gene: {total_genes:,}")
    print(f"   - Tổng số Chromosome: {total_chroms:,}")
    print(f"   - Phân phối nhãn: Pathogenic = {patho_count:,} ({patho_count/total_variants*100:.2f}%) | Benign = {benign_count:,} ({benign_count/total_variants*100:.2f}%)")
    
    # 2. KIỂM TRA ĐIỀU KIỆN LỌC GENE
    gene_label_counts = df.groupby('SYMBOL')['Label'].nunique()
    single_label_genes = (gene_label_counts == 1).sum()
    print("\n2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:")
    print(f"   - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): {single_label_genes:,}")
    if "BỘ 1" not in name:
        print(f"     => Tình trạng: {'✅ PASS (Đạt 0 như yêu cầu)' if single_label_genes == 0 else '❌ FAIL'}")

    # 3. PHÂN BỔ THEO TẬP TRAIN / VAL / TEST
    print("\n3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:")
    split_stats = df.groupby('Split').agg(
        Variants=('Variant_ID', 'count'),
        Genes=('SYMBOL', 'nunique'),
        Chromosomes=('CHROM', 'nunique'),
        Pathogenic=('Label', 'sum')
    ).reset_index()
    
    split_stats['Benign'] = split_stats['Variants'] - split_stats['Pathogenic']
    split_stats['% Tổng'] = (split_stats['Variants'] / total_variants * 100).round(2)
    split_stats['% Patho'] = (split_stats['Pathogenic'] / split_stats['Variants'] * 100).round(2)
    
    print(split_stats[['Split', 'Variants', '% Tổng', 'Pathogenic', 'Benign', '% Patho', 'Genes', 'Chromosomes']].to_string(index=False))

    # 4. KIỂM TRA CHỐNG RÒ RỈ DATA (DATA LEAKAGE)
    print("\n4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:")
    train_genes = set(df[df['Split'] == 'Train']['SYMBOL'])
    val_genes = set(df[df['Split'] == 'Val']['SYMBOL'])
    test_genes = set(df[df['Split'] == 'Test']['SYMBOL'])
    
    overlap_tv = len(train_genes.intersection(val_genes))
    overlap_tt = len(train_genes.intersection(test_genes))
    overlap_vt = len(val_genes.intersection(test_genes))
    
    total_overlaps = overlap_tv + overlap_tt + overlap_vt
    print(f"   - Trùng lặp Gene: Train-Val ({overlap_tv}) | Train-Test ({overlap_tt}) | Val-Test ({overlap_vt})")
    print(f"     => Tình trạng Leakage: {'✅ AN TOÀN (0 Trùng lặp)' if total_overlaps == 0 else '❌ BỊ LEAK DATA'}")

    # =======================================================
    # TÍNH NĂNG 5 MỚI: THỐNG KÊ NHÃN MỖI CHROMOSOME
    # =======================================================
    print("\n5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:")
    chr_stats = df.groupby('CHROM').agg(
        Total=('Variant_ID', 'count'),
        Pathogenic=('Label', 'sum')
    ).reset_index()
    chr_stats['Benign'] = chr_stats['Total'] - chr_stats['Pathogenic']
    chr_stats['% Patho'] = (chr_stats['Pathogenic'] / chr_stats['Total'] * 100).round(2)
    chr_stats = chr_stats.sort_values('Total', ascending=False)
    
    # In toàn bộ danh sách Chromosome
    print(chr_stats.to_string(index=False))

    # =======================================================
    # TÍNH NĂNG 6 MỚI: THỐNG KÊ NHÃN MỖI GENE
    # =======================================================
    print(f"\n6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / {total_genes:,} GENE):")
    gene_stats = df.groupby('SYMBOL').agg(
        Total=('Variant_ID', 'count'),
        Pathogenic=('Label', 'sum')
    ).reset_index()
    gene_stats['Benign'] = gene_stats['Total'] - gene_stats['Pathogenic']
    gene_stats['% Patho'] = (gene_stats['Pathogenic'] / gene_stats['Total'] * 100).round(2)
    gene_stats = gene_stats.sort_values('Total', ascending=False)
    
    print(gene_stats.head(15).to_string(index=False))
    print("...\n\n")

# =========================================================
# GỌI HÀM KIỂM TRA
# =========================================================

# Chạy thử nghiệm trên 3 bộ dữ liệu
eda_dataset(df_bo1, "BỘ 1 (Chỉ chia Chromosome, giữ nguyên gốc)")
eda_dataset(df_bo2, "BỘ 2 (Lọc bỏ các Gene chỉ chứa 1 loại Nhãn)")
eda_dataset(df_bo3, "BỘ 3 (Downsampling ép tỷ lệ 50:50)")
# Out:
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 1 (Chỉ chia Chromosome, giữ nguyên gốc)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 129,950
#    - Tổng số Gene: 12,336
#    - Tổng số Chromosome: 24
#    - Phân phối nhãn: Pathogenic = 30,254.0 (23.28%) | Benign = 99,696.0 (76.72%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 9,328
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test     11864    9.13      2907.0  8957.0    24.50   1271            4
# Train    104385   80.33     24733.0 79652.0    23.69   9514           16
#   Val     13701   10.54      2614.0 11087.0    19.08   1551            4
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     1  12435      2933.0  9502.0    23.59
#     2  10418      2838.0  7580.0    27.24
#     X   8303      2915.0  5388.0    35.11
#    17   7683      2017.0  5666.0    26.25
#     7   7610      1605.0  6005.0    21.09
#     3   7472      1946.0  5526.0    26.04
#    12   6905      1833.0  5072.0    26.55
#     5   6427      1111.0  5316.0    17.29
#    11   6278      1683.0  4595.0    26.81
#     9   6263      1147.0  5116.0    18.31
#    16   5767      1123.0  4644.0    19.47
#     6   5704       985.0  4719.0    17.27
#    19   4538      1060.0  3478.0    23.36
#    15   4456      1348.0  3108.0    30.25
#    14   4383      1032.0  3351.0    23.55
#    10   4123       830.0  3293.0    20.13
#     4   4076       644.0  3432.0    15.80
#     8   3905       568.0  3337.0    14.55
#    20   3284       729.0  2555.0    22.20
#    13   3052       638.0  2414.0    20.90
#    22   2682       466.0  2216.0    17.38
#    18   2405       444.0  1961.0    18.46
#    21   1780       359.0  1421.0    20.17
#     Y      1         0.0     1.0     0.00
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 12,336 GENE):
# SYMBOL  Total  Pathogenic  Benign  % Patho
# DNAH11   1072        14.0  1058.0     1.31
#  KMT2D   1014        40.0   974.0     3.94
#   FBN1    677       614.0    63.0    90.69
#  BRCA2    661        45.0   616.0     6.81
# ADGRV1    612        12.0   600.0     1.96
#  SCN1A    500       451.0    49.0    90.20
#  OBSCN    473         1.0   472.0     0.21
#  BRCA1    463        53.0   410.0    11.45
#  DNAH5    432        25.0   407.0     5.79
#   SACS    425        27.0   398.0     6.35
#   APOB    390        10.0   380.0     2.56
#  KMT2C    382         8.0   374.0     2.09
# COL4A5    370       267.0   103.0    72.16
#   NSD1    332        96.0   236.0    28.92
#   ATRX    330        29.0   301.0     8.79
# ...
#
#
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 2 (Lọc bỏ các Gene chỉ chứa 1 loại Nhãn)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 82,763
#    - Tổng số Gene: 3,008
#    - Tổng số Chromosome: 23
#    - Phân phối nhãn: Pathogenic = 29,120.0 (35.18%) | Benign = 53,643.0 (64.82%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 0
#      => Tình trạng: ✅ PASS (Đạt 0 như yêu cầu)
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test      6863    8.29      2782.0  4081.0    40.54    325            3
# Train     67990   82.15     23828.0 44162.0    35.05   2340           16
#   Val      7910    9.56      2510.0  5400.0    31.73    343            4
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     1   7629      2727.0  4902.0    35.75
#     2   7300      2715.0  4585.0    37.19
#     X   6490      2875.0  3615.0    44.30
#    17   5205      1999.0  3206.0    38.41
#     7   5060      1507.0  3553.0    29.78
#    12   4569      1763.0  2806.0    38.59
#     5   4386      1082.0  3304.0    24.67
#     3   4342      1894.0  2448.0    43.62
#     9   4108      1132.0  2976.0    27.56
#    16   3683      1092.0  2591.0    29.65
#    11   3625      1633.0  1992.0    45.05
#     6   3453       952.0  2501.0    27.57
#    19   2702       993.0  1709.0    36.75
#    15   2628      1321.0  1307.0    50.27
#    14   2587      1013.0  1574.0    39.16
#     8   2402       533.0  1869.0    22.19
#     4   2275       627.0  1648.0    27.56
#    10   2272       782.0  1490.0    34.42
#    13   2138       630.0  1508.0    29.47
#    20   1963       679.0  1284.0    34.59
#    18   1516       438.0  1078.0    28.89
#    22   1417       452.0   965.0    31.90
#    21   1013       281.0   732.0    27.74
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 3,008 GENE):
# SYMBOL  Total  Pathogenic  Benign  % Patho
# DNAH11   1072        14.0  1058.0     1.31
#  KMT2D   1014        40.0   974.0     3.94
#   FBN1    677       614.0    63.0    90.69
#  BRCA2    661        45.0   616.0     6.81
# ADGRV1    612        12.0   600.0     1.96
#  SCN1A    500       451.0    49.0    90.20
#  OBSCN    473         1.0   472.0     0.21
#  BRCA1    463        53.0   410.0    11.45
#  DNAH5    432        25.0   407.0     5.79
#   SACS    425        27.0   398.0     6.35
#   APOB    390        10.0   380.0     2.56
#  KMT2C    382         8.0   374.0     2.09
# COL4A5    370       267.0   103.0    72.16
#   NSD1    332        96.0   236.0    28.92
#   ATRX    330        29.0   301.0     8.79
# ...
#
#
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 3 (Downsampling ép tỷ lệ 50:50)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 28,502
#    - Tổng số Gene: 3,008
#    - Tổng số Chromosome: 23
#    - Phân phối nhãn: Pathogenic = 14,251.0 (50.00%) | Benign = 14,251.0 (50.00%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 0
#      => Tình trạng: ✅ PASS (Đạt 0 như yêu cầu)
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test      2380    8.35      1190.0  1190.0     50.0    325            3
# Train     23208   81.43     11604.0 11604.0     50.0   2340           16
#   Val      2914   10.22      1457.0  1457.0     50.0    343            4
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     2   2656      1328.0  1328.0     50.0
#     X   2482      1241.0  1241.0     50.0
#     1   2294      1147.0  1147.0     50.0
#    17   2028      1014.0  1014.0     50.0
#     3   1838       919.0   919.0     50.0
#    12   1566       783.0   783.0     50.0
#     5   1474       737.0   737.0     50.0
#     9   1432       716.0   716.0     50.0
#    11   1388       694.0   694.0     50.0
#    16   1354       677.0   677.0     50.0
#    19   1196       598.0   598.0     50.0
#     6   1092       546.0   546.0     50.0
#     7   1056       528.0   528.0     50.0
#    14    954       477.0   477.0     50.0
#    15    922       461.0   461.0     50.0
#     4    858       429.0   429.0     50.0
#    10    818       409.0   409.0     50.0
#     8    664       332.0   332.0     50.0
#    20    640       320.0   320.0     50.0
#    13    558       279.0   279.0     50.0
#    22    438       219.0   219.0     50.0
#    18    422       211.0   211.0     50.0
#    21    372       186.0   186.0     50.0
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 3,008 GENE):
#  SYMBOL  Total  Pathogenic  Benign  % Patho
#    TP53    270       135.0   135.0     50.0
#   USH2A    266       133.0   133.0     50.0
#  COL2A1    238       119.0   119.0     50.0
#  COL4A5    206       103.0   103.0     50.0
# CACNA1A    196        98.0    98.0     50.0
#  COL1A1    192        96.0    96.0     50.0
#    NSD1    192        96.0    96.0     50.0
#  COL7A1    188        94.0    94.0     50.0
#    MSH2    158        79.0    79.0     50.0
# DYNC1H1    156        78.0    78.0     50.0
# SMARCA2    130        65.0    65.0     50.0
#   KIF1A    130        65.0    65.0     50.0
#   PKHD1    128        64.0    64.0     50.0
#   CDKL5    128        64.0    64.0     50.0
#    FBN1    126        63.0    63.0     50.0
# ...

# %%
# 2. MÃ HÓA ĐỘ TIN CẬY REVIEW STATUS
print("[2/6] Đang đánh giá Rank cho ReviewStatus...")
review_priority = {
    'practice guideline': 5,
    'reviewed by expert panel': 4,
    'criteria provided, multiple submitters, no conflicts': 3,
    'criteria provided, single submitter': 2,
    'criteria provided, conflicting classifications': 1
}
df['Review_Rank'] = df['ReviewStatus'].map(review_priority).fillna(0)

# =========================================================
# XỬ LÝ THỜI GIAN (YEAR) TRƯỚC KHI CHIA CHROMOSOME
# =========================================================
print("[3/6] Đang trích xuất thời gian và loại bỏ biến thể không có ngày tháng...")
df['Year'] = pd.to_datetime(df['LastEvaluated'], errors='coerce').dt.year

# Bắt buộc drop các dòng không có năm để đảm bảo tính nghiêm ngặt của Time-split
df_time = df.dropna(subset=['Year']).copy()

# =========================================================
# THUẬT TOÁN GREEDY THÔNG MINH (TIME-AWARE CHROMOSOME SPLIT)
# =========================================================
print("[4/6] Đang chạy thuật toán phân bổ Chromosome (80-10-10 kết hợp Thời gian)...")

# Tính "sản lượng" biến thể hợp lệ của mỗi Chromosome nếu đưa vào từng Rương
chr_stats = []
for chrom, group in df_time.groupby('CHROM'):
    chr_stats.append({
        'CHROM': chrom,
        'Yield_Train': (group['Year'] <= 2024).sum(),
        'Yield_Val': (group['Year'] == 2025).sum(),
        'Yield_Test': (group['Year'] >= 2026).sum(),
        'Total': len(group)
    })
chr_df = pd.DataFrame(chr_stats).sort_values('Total', ascending=False)

# Ước lượng tổng số variant sẽ giữ lại được (để tính target 80-10-10)
estimated_kept = chr_df[['Yield_Train', 'Yield_Val', 'Yield_Test']].max(axis=1).sum()
targets = {
    'Train': estimated_kept * 0.80,
    'Val': estimated_kept * 0.10,
    'Test': estimated_kept * 0.10
}

splits = {'Train': [], 'Val': [], 'Test': []}
current_counts = {'Train': 0, 'Val': 0, 'Test': 0}

for _, row in chr_df.iterrows():
    chrom = row['CHROM']
    yields = {
        'Train': row['Yield_Train'], 
        'Val': row['Yield_Val'], 
        'Test': row['Yield_Test']
    }
    
    # Tính mức độ thiếu hụt của các rương
    deficits = {k: targets[k] - current_counts[k] for k in targets}
    
    # Sắp xếp rương theo độ "đói" dữ liệu giảm dần
    sorted_splits = sorted(deficits.keys(), key=lambda k: deficits[k], reverse=True)
    
    # Chọn rương "đói" nhất MÀ CÓ THỂ CUNG CẤP DỮ LIỆU (> 0)
    best_split = sorted_splits[0]
    for s in sorted_splits:
        if yields[s] > 0:
            best_split = s
            break
            
    # Gán Chromosome vào rương đã chọn
    splits[best_split].append(chrom)
    current_counts[best_split] += yields[best_split]

# =========================================================
# LỌC NGHIÊM NGẶT THEO ĐIỀU KIỆN THỜI GIAN
# =========================================================
def get_split(chrom):
    if chrom in splits['Train']: return 'Train'
    elif chrom in splits['Val']: return 'Val'
    elif chrom in splits['Test']: return 'Test'
    else: return 'Drop'

df_time['Temp_Split'] = df_time['CHROM'].apply(get_split)

# CHỈ GIỮ LẠI CÁC BIẾN THỂ THỎA MÃN CHÍNH XÁC NĂM CỦA RƯƠNG ĐÓ (Bước này xén bớt data thừa)
cond_train = (df_time['Temp_Split'] == 'Train') & (df_time['Year'] <= 2024)
cond_val   = (df_time['Temp_Split'] == 'Val')   & (df_time['Year'] == 2025)
cond_test  = (df_time['Temp_Split'] == 'Test')  & (df_time['Year'] >= 2026)

# Đây là DataFrame KHỞI NGUỒN CHÍNH THỨC, đã sạch sẽ 100% về không gian và thời gian
df_filtered = df_time[cond_train | cond_val | cond_test].copy()
df_filtered.rename(columns={'Temp_Split': 'Split'}, inplace=True)

print("\n--- KẾT QUẢ CHIA CHROMOSOME KẾT HỢP TIME-SPLIT ---")
final_total = len(df_filtered)
for k in splits:
    actual_count = len(df_filtered[df_filtered['Split'] == k])
    pct = actual_count / final_total * 100 if final_total > 0 else 0
    print(f"{k} ({pct:.2f}% | {actual_count:,} variants): Chromosomes {splits[k]}")
print(f"Tổng số Variant hợp lệ giữ lại: {final_total:,} (Mất {len(df) - final_total:,} do thiếu ngày hoặc khác năm)")
print("--------------------------------------------------\n")

# =========================================================
# TẠO BỘ 1: GỐC (Đã xén theo Time & Chromosome)
# =========================================================
print("[5/6] Đang xuất các Bộ dữ liệu...")
df_bo1 = df_filtered.copy()

# =========================================================
# TẠO BỘ 2: LỌC BỎ GENE CHỈ CÓ 1 NHÃN
# =========================================================
gene_label_counts = df_bo1.groupby('SYMBOL')['Label'].nunique()
valid_genes = gene_label_counts[gene_label_counts == 2].index
df_bo2 = df_bo1[df_bo1['SYMBOL'].isin(valid_genes)].copy()

# =========================================================
# TẠO BỘ 3: DOWNSAMPLING 50:50 THEO REVIEW RANK
# =========================================================
# Bước A: Sắp xếp
df_bo3_temp = df_bo2.sort_values(by=['SYMBOL', 'Label', 'Review_Rank'], ascending=[True, True, False])

# Bước B: Đánh số thứ tự
df_bo3_temp['Row_Num'] = df_bo3_temp.groupby(['SYMBOL', 'Label']).cumcount()

# Bước C: Tính giới hạn Min_Count
class_counts = df_bo3_temp.groupby(['SYMBOL', 'Label']).size().unstack(fill_value=0)
class_counts['Min_Count'] = class_counts.min(axis=1)

# Bước D: Ghép và Lọc
df_bo3 = df_bo3_temp.merge(class_counts[['Min_Count']], on='SYMBOL', how='left')
df_bo3 = df_bo3[df_bo3['Row_Num'] < df_bo3['Min_Count']].copy()

# Dọn dẹp
df_bo3 = df_bo3.drop(columns=['Row_Num', 'Min_Count'])
# Out:
# [2/6] Đang đánh giá Rank cho ReviewStatus...
# [3/6] Đang trích xuất thời gian và loại bỏ biến thể không có ngày tháng...
# [4/6] Đang chạy thuật toán phân bổ Chromosome (80-10-10 kết hợp Thời gian)...
#
# --- KẾT QUẢ CHIA CHROMOSOME KẾT HỢP TIME-SPLIT ---
# Train (87.84% | 44,860 variants): Chromosomes ['1', '2', '17', 'X', '7', '3', '12', '5', '11', '9', '6', '16', '15', '13', 'Y']
# Val (6.10% | 3,115 variants): Chromosomes ['19', '10', '22']
# Test (6.06% | 3,093 variants): Chromosomes ['14', '4', '8', '20', '18', '21']
# Tổng số Variant hợp lệ giữ lại: 51,068 (Mất 58,952 do thiếu ngày hoặc khác năm)
# --------------------------------------------------
#
# [5/6] Đang xuất các Bộ dữ liệu...

# %%
# Chạy thử nghiệm trên 3 bộ dữ liệu
eda_dataset(df_bo1, "BỘ 1 (Chỉ chia Chromosome, giữ nguyên gốc)")
eda_dataset(df_bo2, "BỘ 2 (Lọc bỏ các Gene chỉ chứa 1 loại Nhãn)")
eda_dataset(df_bo3, "BỘ 3 (Downsampling ép tỷ lệ 50:50)")
# Out:
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 1 (Chỉ chia Chromosome, giữ nguyên gốc)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 51,068
#    - Tổng số Gene: 9,259
#    - Tổng số Chromosome: 24
#    - Phân phối nhãn: Pathogenic = 8,596 (16.83%) | Benign = 42,472 (83.17%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 7,847
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test      3093    6.06         216    2877     6.98    524            6
# Train     44860   87.84        7955   36905    17.73   7833           15
#   Val      3115    6.10         425    2690    13.64    902            3
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     1   5564         842    4722    15.13
#     2   4677         999    3678    21.36
#     X   3723        1043    2680    28.02
#     7   3635         575    3060    15.82
#    17   3568         687    2881    19.25
#     3   3409         652    2757    19.13
#    12   3275         667    2608    20.37
#     5   3005         391    2614    13.01
#    11   2853         508    2345    17.81
#     9   2675         361    2314    13.50
#     6   2580         300    2280    11.63
#    16   2468         342    2126    13.86
#    15   1998         426    1572    21.32
#    13   1429         162    1267    11.34
#    19   1232         172    1060    13.96
#    10   1142         158     984    13.84
#     4    748          32     716     4.28
#    22    741          95     646    12.82
#    14    618          70     548    11.33
#     8    561          22     539     3.92
#    20    483          31     452     6.42
#    18    361          31     330     8.59
#    21    322          30     292     9.32
#     Y      1           0       1     0.00
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 9,259 GENE):
# SYMBOL  Total  Pathogenic  Benign  % Patho
# DNAH11    582           1     581     0.17
#  KMT2D    417          14     403     3.36
#  OBSCN    309           0     309     0.00
# ADGRV1    290           3     287     1.03
#   FBN1    282         253      29    89.72
#  BRCA2    278          14     264     5.04
#  BRCA1    277          20     257     7.22
#   SACS    263           7     256     2.66
#  SCN1A    248         223      25    89.92
#  KMT2C    212           0     212     0.00
#   ATRX    198           9     189     4.55
#  DNAH5    193           6     187     3.11
#   MSH2    188          28     160    14.89
#   NSD1    156          36     120    23.08
#  EHMT1    154           2     152     1.30
# ...
#
#
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 2 (Lọc bỏ các Gene chỉ chứa 1 loại Nhãn)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 21,370
#    - Tổng số Gene: 1,412
#    - Tổng số Chromosome: 23
#    - Phân phối nhãn: Pathogenic = 7,230 (33.83%) | Benign = 14,140 (66.17%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 0
#      => Tình trạng: ✅ PASS (Đạt 0 như yêu cầu)
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test       601    2.81         163     438    27.12     68            6
# Train     19973   93.46        6733   13240    33.71   1274           14
#   Val       796    3.72         334     462    41.96     70            3
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     2   2400         902    1498    37.58
#     X   2263         918    1345    40.57
#     1   2002         635    1367    31.72
#    17   1721         635    1086    36.90
#     7   1622         492    1130    30.33
#    12   1593         615     978    38.61
#     5   1532         339    1193    22.13
#     9   1253         295     958    23.54
#     3   1190         524     666    44.03
#    16   1018         272     746    26.72
#     6    964         211     753    21.89
#    11    904         358     546    39.60
#    13    775         147     628    18.97
#    15    736         390     346    52.99
#    19    345         132     213    38.26
#    10    236         128     108    54.24
#    22    215          74     141    34.42
#    14    149          37     112    24.83
#     4    112          26      86    23.21
#    20     91          24      67    26.37
#     8     87          21      66    24.14
#    18     83          27      56    32.53
#    21     79          28      51    35.44
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 1,412 GENE):
# SYMBOL  Total  Pathogenic  Benign  % Patho
# DNAH11    582           1     581     0.17
#  KMT2D    417          14     403     3.36
# ADGRV1    290           3     287     1.03
#   FBN1    282         253      29    89.72
#  BRCA2    278          14     264     5.04
#  BRCA1    277          20     257     7.22
#   SACS    263           7     256     2.66
#  SCN1A    248         223      25    89.92
#   ATRX    198           9     189     4.55
#  DNAH5    193           6     187     3.11
#   MSH2    188          28     160    14.89
#   NSD1    156          36     120    23.08
#  EHMT1    154           2     152     1.30
#   APOB    153           2     151     1.31
#  MACF1    143           2     141     1.40
# ...
#
#
# ============================================================
# 🌟 BÁO CÁO EDA CHI TIẾT: BỘ 3 (Downsampling ép tỷ lệ 50:50)
# ============================================================
# 1. TỔNG QUAN KÍCH THƯỚC:
#    - Tổng số biến thể: 7,230
#    - Tổng số Gene: 1,412
#    - Tổng số Chromosome: 23
#    - Phân phối nhãn: Pathogenic = 3,615 (50.00%) | Benign = 3,615 (50.00%)
#
# 2. KIỂM TRA TÍNH HỢP LỆ CỦA GENE:
#    - Số Gene chỉ có 1 nhãn (Patho hoặc Benign): 0
#      => Tình trạng: ✅ PASS (Đạt 0 như yêu cầu)
#
# 3. PHÂN PHỐI DỮ LIỆU CHIA TẬP:
# Split  Variants  % Tổng  Pathogenic  Benign  % Patho  Genes  Chromosomes
#  Test       256    3.54         128     128     50.0     68            6
# Train      6640   91.84        3320    3320     50.0   1274           14
#   Val       334    4.62         167     167     50.0     70            3
#
# 4. KIỂM TRA CHỐNG RÒ RỈ (LEAKAGE) TẬP DỮ LIỆU:
#    - Trùng lặp Gene: Train-Val (0) | Train-Test (0) | Val-Test (0)
#      => Tình trạng Leakage: ✅ AN TOÀN (0 Trùng lặp)
#
# 5. THỐNG KÊ NHÃN THEO TỪNG CHROMOSOME:
# CHROM  Total  Pathogenic  Benign  % Patho
#     X    918         459     459     50.0
#     2    762         381     381     50.0
#    17    668         334     334     50.0
#     1    636         318     318     50.0
#     3    562         281     281     50.0
#    12    514         257     257     50.0
#     5    476         238     238     50.0
#     9    406         203     203     50.0
#    11    374         187     187     50.0
#    16    350         175     175     50.0
#     7    302         151     151     50.0
#     6    258         129     129     50.0
#    15    252         126     126     50.0
#    19    166          83      83     50.0
#    13    162          81      81     50.0
#    10    112          56      56     50.0
#    14     60          30      30     50.0
#    22     56          28      28     50.0
#     4     48          24      24     50.0
#    20     46          23      23     50.0
#    18     40          20      20     50.0
#    21     32          16      16     50.0
#     8     30          15      15     50.0
#
# 6. THỐNG KÊ NHÃN THEO TỪNG GENE (HIỂN THỊ TOP 15 / 1,412 GENE):
#  SYMBOL  Total  Pathogenic  Benign  % Patho
#    TP53     98          49      49     50.0
#  COL4A5     96          48      48     50.0
#  COL2A1     86          43      43     50.0
#    NSD1     72          36      36     50.0
#  COL7A1     68          34      34     50.0
#   USH2A     60          30      30     50.0
#    FBN1     58          29      29     50.0
#  COL1A1     58          29      29     50.0
# SMARCA2     56          28      28     50.0
#    MSH2     56          28      28     50.0
#   CDKL5     56          28      28     50.0
#    MLH1     50          25      25     50.0
#   SCN1A     50          25      25     50.0
#  GRIN2A     44          22      22     50.0
#   BRCA1     40          20      20     50.0
# ...

# %%
# Lưu ra ổ cứng (Bạn có thể sửa lại tên file)
df_bo1[df_bo1['Split'] == 'Train'].to_parquet("train1.parquet")
df_bo1[df_bo1['Split'] == 'Val'].to_parquet("val1.parquet")
df_bo1[df_bo1['Split'] == 'Test'].to_parquet("test1.parquet")

df_bo2[df_bo2['Split'] == 'Train'].to_parquet("train2.parquet")
df_bo2[df_bo2['Split'] == 'Val'].to_paparquet("val2.parquet")
df_bo2[df_bo2['Split'] == 'Test'].to_parquet("test2.parquet")

df_bo3[df_bo3['Split'] == 'Train'].to_parquet("train3.parquet")
df_bo3[df_bo3['Split'] == 'Val'].to_paparquet("val3.parquet")
df_bo3[df_bo3['Split'] == 'Test'].to_parquet("test3.parquet")

print("\nHOÀN TẤT XUẤT 9 FILE DATASET!")

# %%
def check_cross_dataset_leakage(df_base, df_target, base_name="Train/Val", target_name="Benchmark Test"):
    """
    Hàm so khớp và kiểm tra rò rỉ dữ liệu giữa 2 tập dataset trên 3 cấp độ:
    Variant_ID, SYMBOL (Gene), CHROM.
    
    Trả về dictionary chứa các tập hợp trùng lặp để bạn có thể dùng để filter (nếu cần).
    """
    print(f"============================================================")
    print(f"🔍 KIỂM TRA RÒ RỈ: [{base_name}] vs [{target_name}]")
    print(f"============================================================")
    
    # Kiểm tra xem các cột cần thiết có tồn tại không
    required_cols = ['Variant_ID', 'SYMBOL', 'CHROM']
    for col in required_cols:
        if col not in df_base.columns or col not in df_target.columns:
            print(f"[LỖI] Cả 2 tập dữ liệu cần phải có cột '{col}'")
            return None

    # 1. Trích xuất các tập hợp (Sets)
    base_vars = set(df_base['Variant_ID'].dropna())
    target_vars = set(df_target['Variant_ID'].dropna())
    
    base_genes = set(df_base['SYMBOL'].dropna())
    target_genes = set(df_target['SYMBOL'].dropna())
    
    base_chroms = set(df_base['CHROM'].astype(str).dropna())
    target_chroms = set(df_target['CHROM'].astype(str).dropna())
    
    # 2. Tìm điểm giao (Intersection)
    overlap_vars = base_vars.intersection(target_vars)
    overlap_genes = base_genes.intersection(target_genes)
    overlap_chroms = base_chroms.intersection(target_chroms)
    
    # 3. In báo cáo
    print(f"1. Cấp độ Variant_ID:")
    print(f"   - Tập {base_name}: {len(base_vars):,} variants")
    print(f"   - Tập {target_name}: {len(target_vars):,} variants")
    if len(overlap_vars) == 0:
        print(f"   => Tình trạng: ✅ AN TOÀN (0 trùng lặp)")
    else:
        print(f"   => Tình trạng: ❌ LEAKAGE ({len(overlap_vars):,} variants trùng lặp)")
        # In thử 3 ID trùng lặp để kiểm tra
        print(f"      (Ví dụ: {list(overlap_vars)[:3]})")

    print(f"\n2. Cấp độ SYMBOL (Gene):")
    print(f"   - Tập {base_name}: {len(base_genes):,} genes")
    print(f"   - Tập {target_name}: {len(target_genes):,} genes")
    if len(overlap_genes) == 0:
        print(f"   => Tình trạng: ✅ AN TOÀN (0 trùng lặp)")
    else:
        print(f"   => Tình trạng: ❌ LEAKAGE ({len(overlap_genes):,} genes trùng lặp)")
        print(f"      (Ví dụ: {list(overlap_genes)[:5]})")

    print(f"\n3. Cấp độ CHROM (Nhiễm sắc thể):")
    print(f"   - Tập {base_name}: {len(base_chroms)} chroms")
    print(f"   - Tập {target_name}: {len(target_chroms)} chroms")
    if len(overlap_chroms) == 0:
        print(f"   => Tình trạng: ✅ AN TOÀN (0 trùng lặp)")
    else:
        print(f"   => Tình trạng: ❌ LEAKAGE ({len(overlap_chroms)} chroms trùng lặp)")
        print(f"      (Danh sách: {overlap_chroms})")
        
    print("\n")
    
    # Trả về các set trùng lặp để bạn có thể code loại bỏ chúng nếu muốn
    return {
        'overlap_variants': overlap_vars,
        'overlap_genes': overlap_genes,
        'overlap_chroms': overlap_chroms
    }

# =========================================================
# VÍ DỤ CÁCH SỬ DỤNG CHO NHIỀU TẬP BENCHMARK
# =========================================================

# Giả sử bạn có 1 dict chứa các tập dataset đọc từ parquet
# benchmark_datasets = {
#     "Benchmark_1_ClinVar_2024": pd.read_parquet("bench1.parquet"),
#     "Benchmark_2_VarSome": pd.read_parquet("bench2.parquet"),
#     "Benchmark_3_Literature": pd.read_parquet("bench3.parquet")
# }

# Giả sử df_bo3_train_val là tập bạn đã gộp từ Train và Val của Bộ 3
# df_bo3_train_val = pd.concat([df_bo3[df_bo3['Split'] == 'Train'], df_bo3[df_bo3['Split'] == 'Val']])

# Chạy vòng lặp kiểm tra toàn bộ
# for bench_name, df_bench in benchmark_datasets.items():
#     overlaps = check_cross_dataset_leakage(
#         df_base=df_bo3_train_val, 
#         df_target=df_bench, 
#         base_name="Train+Val (Bộ 3)", 
#         target_name=bench_name
#     )
    
#     # Nếu phát hiện trùng variant, bạn có thể tự động TẨY RỬA tập Benchmark như sau:
#     # if len(overlaps['overlap_variants']) > 0:
#     #     df_bench_clean = df_bench[~df_bench['Variant_ID'].isin(overlaps['overlap_variants'])]
#     #     print(f"Đã dọn dẹp xong tập {bench_name}, còn lại {len(df_bench_clean)} variants sạch.")
